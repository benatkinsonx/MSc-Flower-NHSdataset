# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
acc1 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy555.npy')

numrounds = np.arange(1,101)

# %% [markdown]
# # $\epsilon = 10$

# %%
mean_acc = np.mean([acc1,acc2,acc4,acc5], axis=0)
std_acc = np.std([acc1,acc2,acc4,acc5], axis=0)

# %%
plt.plot(numrounds, acc1, label='acc1')
plt.plot(numrounds, acc2, label='acc2')
# plt.plot(numrounds, acc3, label='acc3')
plt.plot(numrounds, acc4, label='acc4')
plt.plot(numrounds, acc5, label='acc5')
plt.legend()

# %%
plt.plot(numrounds, mean_acc, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc - std_acc, mean_acc + std_acc, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # $\epsilon = 8$

# %%
acc1 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\logDP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy555.npy')

# %%
mean_acc = np.mean([acc1,acc3,acc4,acc5], axis=0)
std_acc = np.std([acc1,acc3,acc4,acc5], axis=0)

# %%
plt.plot(numrounds, acc1, label='acc1')
# plt.plot(numrounds, acc2, label='acc2')
plt.plot(numrounds, acc3, label='acc3')
plt.plot(numrounds, acc4, label='acc4')
plt.plot(numrounds, acc5, label='acc5')
plt.legend()

# %%
plt.plot(numrounds, mean_acc, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc - std_acc, mean_acc + std_acc, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # no scaling $\epsilon=10$

# %%
acc1_10 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2_10 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3_10 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4_10 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5_10 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps10_datanorm20_C0.25_iterperround1_accuracy555.npy')

# %%
plt.plot(numrounds, acc1_10, label='acc1')
plt.plot(numrounds, acc2_10, label='acc2')
# plt.plot(numrounds, acc3_10, label='acc3')
plt.plot(numrounds, acc4_10, label='acc4')
plt.plot(numrounds, acc5_10, label='acc5')
plt.legend()

# %%
import pandas as pd

# %%
mean_acc_10 = np.mean([acc1_10,acc2_10,acc4_10,acc5_10], axis=0)
std_acc_10 = np.std([acc1_10,acc2_10,acc4_10,acc5_10], axis=0)

WINDOW = 5

rollingmean_acc_10 = pd.Series(mean_acc_10).rolling(window=WINDOW, center=True).mean()
rollingstd_acc_10 = pd.Series(std_acc_10).rolling(window=WINDOW, center=True).mean()

num_rounds = np.arange(1,len(rollingmean_acc_10)+1)

# %%
plt.plot(numrounds, rollingmean_acc_10, label='Mean Accuracy')
plt.fill_between(num_rounds, rollingmean_acc_10 - rollingstd_acc_10, rollingmean_acc_10 + rollingstd_acc_10, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(numrounds, mean_acc_10, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc_10 - std_acc_10, mean_acc_10 + std_acc_10, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # no scaling $\epsilon=5$

# %%
acc1_5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2_5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3_5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4_5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5_5 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps5_datanorm20_C0.25_iterperround1_accuracy555.npy')

# %%
plt.plot(numrounds, acc1_5, label='acc1')
plt.plot(numrounds, acc2_5, label='acc2')
plt.plot(numrounds, acc3_5, label='acc3')
plt.plot(numrounds, acc4_5, label='acc4')
plt.plot(numrounds, acc5_5, label='acc5')
plt.legend()

# %%
mean_acc_5 = np.mean([acc1,acc2,acc3,acc4,acc5], axis=0)
std_acc_5 = np.std([acc1,acc2,acc3,acc4,acc5], axis=0)

WINDOW = 5

rollingmean_acc_5 = pd.Series(mean_acc_5).rolling(window=WINDOW, center=True).mean()
rollingstd_acc_5 = pd.Series(std_acc_5).rolling(window=WINDOW, center=True).mean()

num_rounds = np.arange(1,len(rollingmean_acc_5)+1)

# %%
plt.plot(numrounds, rollingmean_acc_5, label='Mean Accuracy')
plt.fill_between(numrounds, rollingmean_acc_5 - rollingstd_acc_5, rollingmean_acc_5 + rollingstd_acc_5, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(numrounds, mean_acc, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc - std_acc, mean_acc + std_acc, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # no scaling $\epsilon=8$

# %%
acc1_8 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps8_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2_8 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps8_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3_8 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps8_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4_8 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps8_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5_8 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps8_datanorm20_C0.25_iterperround1_accuracy555.npy')

# %%
plt.plot(numrounds, acc1, label='acc1')
plt.plot(numrounds, acc2, label='acc2')
plt.plot(numrounds, acc3, label='acc3')
# plt.plot(numrounds, acc4, label='acc4')
plt.plot(numrounds, acc5, label='acc5')
plt.legend()

# %%
mean_acc_8 = np.mean([acc1_8,acc2_8,acc3_8,acc5_8], axis=0)
std_acc_8 = np.std([acc1_8,acc2_8,acc3_8,acc5_8], axis=0)


WINDOW = 5

rollingmean_acc_8 = pd.Series(mean_acc_8).rolling(window=WINDOW, center=True).mean()
rollingstd_acc_8 = pd.Series(std_acc_8).rolling(window=WINDOW, center=True).mean()

num_rounds = np.arange(1,len(rollingmean_acc_8)+1)

# %%
plt.plot(numrounds, rollingmean_acc_8, label='Mean Accuracy')
plt.fill_between(numrounds, rollingmean_acc_8 - rollingstd_acc_8, rollingmean_acc_8 + rollingstd_acc_8, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(numrounds, mean_acc, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc - std_acc, mean_acc + std_acc, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # no scaling $\epsilon=6$

# %%
acc1_6 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps6_datanorm20_C0.25_iterperround1_accuracy111.npy')
acc2_6 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps6_datanorm20_C0.25_iterperround1_accuracy222.npy')
acc3_6 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps6_datanorm20_C0.25_iterperround1_accuracy333.npy')
acc4_6 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps6_datanorm20_C0.25_iterperround1_accuracy444.npy')
acc5_6 = np.load(r'C:\0.MScProjectCode\MSc-Flower-NHSdataset\X_DP_federated_logistic_regression_3clients_eps6_datanorm20_C0.25_iterperround1_accuracy555.npy')

# %%
plt.plot(numrounds, acc1, label='acc1')
plt.plot(numrounds, acc2, label='acc2')
plt.plot(numrounds, acc3, label='acc3')
plt.plot(numrounds, acc4, label='acc4')
plt.plot(numrounds, acc5, label='acc5')
plt.legend()

# %%
mean_acc_6 = np.mean([acc1_6,acc2_6,acc3_6,acc4_6,acc5_6], axis=0)
std_acc_6 = np.std([acc1_6,acc2_6,acc3_6,acc4_6,acc5_6], axis=0)

WINDOW = 5

rollingmean_acc_6 = pd.Series(mean_acc_6).rolling(window=WINDOW, center=True).mean()
rollingstd_acc_6 = pd.Series(std_acc_6).rolling(window=WINDOW, center=True).mean()

num_rounds = np.arange(1,len(rollingmean_acc_6)+1)

# %%
plt.plot(numrounds, rollingmean_acc_6, label='Mean Accuracy')
plt.fill_between(numrounds, rollingmean_acc_6 - rollingstd_acc_6, rollingmean_acc_6 + rollingstd_acc_6, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(numrounds, mean_acc, label='Mean Accuracy')
plt.fill_between(numrounds, mean_acc - std_acc, mean_acc + std_acc, alpha=0.3, label='±1 Std Dev')
plt.xlabel('Round')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(numrounds, rollingmean_acc_5, label='$\epsilon = 5$')
plt.fill_between(num_rounds, rollingmean_acc_5 - rollingstd_acc_5, rollingmean_acc_5 + rollingstd_acc_5, alpha=0.15)

plt.plot(numrounds, rollingmean_acc_8, label='$\epsilon = 7.5$')
plt.fill_between(num_rounds, rollingmean_acc_8 - rollingstd_acc_8, rollingmean_acc_8 + rollingstd_acc_8, alpha=0.2)

plt.plot(numrounds, rollingmean_acc_10, label='$\epsilon = 10$')
plt.fill_between(num_rounds, rollingmean_acc_10 - rollingstd_acc_10, rollingmean_acc_10 + rollingstd_acc_10, alpha=0.3)

plt.xlabel('Training Round', fontsize=15)
plt.ylabel('Test Accuracy', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True, linestyle='--', alpha=0.7)
plt.minorticks_on()
plt.tick_params(axis='both', which='minor', length=4, color='gray', labelsize=15)
plt.tick_params(axis='both', which='major', length=6, color='black', labelsize=15)
plt.tick_params(top=True, right=True, direction='in', length=6)
plt.tick_params(which='minor', top=True, right=True, direction='in', length=4)
plt.legend(fontsize=13.5, ncol=3)

plt.savefig(f'logreg_accuracy_fillbetween.pdf', format='pdf', bbox_inches='tight')
